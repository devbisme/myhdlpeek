# %%
from IPython.core.display import HTML
HTML(open('custom.css', 'r').read())
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# //@import url('http://fonts.googleapis.com/css?family=Open+Sans');
# //@import url('http://fonts.googleapis.com/css?family=Vollkorn');
# //@import url('http://fonts.googleapis.com/css?family=Karla');
# //@import url('http://fonts.googleapis.com/css?family=Poppins');
# //@import url('http://fonts.googleapis.com/css?family=Arimo');
# //@import url('http://fonts.googleapis.com/css?family=Roboto');
# //@import url('http://fonts.googleapis.com/css?family=Lato');
# //@import url('http://fonts.googleapis.com/css?family=Domine');
# //@import url('http://fonts.googleapis.com/css?family=Chivo');
# //@import url('http://fonts.googleapis.com/css?family=Cardo');
# //@import url('http://fonts.googleapis.com/css?family=Arvo');
# //@import url('http://fonts.googleapis.com/css?family=Crimson+Text');
# ...

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Installation" data-toc-modified-id="Installation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Installation</a></span></li><li><span><a href="#Simple-Multiplexer-Example" data-toc-modified-id="Simple-Multiplexer-Example-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Simple Multiplexer Example</a></span><ul class="toc-item"><li><span><a href="#MyHDL-Version" data-toc-modified-id="MyHDL-Version-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>MyHDL Version</a></span></li><li><span><a href="#Amaranth-Version" data-toc-modified-id="Amaranth-Version-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Amaranth Version</a></span></li></ul></li><li><span><a href="#Hierarchical-Examples" data-toc-modified-id="Hierarchical-Examples-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Hierarchical Examples</a></span><ul class="toc-item"><li><span><a href="#An-Adder-in-MyHDL" data-toc-modified-id="An-Adder-in-MyHDL-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>An Adder in MyHDL</a></span></li><li><span><a href="#An-ALU-in-Amaranth" data-toc-modified-id="An-ALU-in-Amaranth-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>An ALU in Amaranth</a></span></li></ul></li><li><span><a href="#Sequential-Examples" data-toc-modified-id="Sequential-Examples-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Sequential Examples</a></span><ul class="toc-item"><li><span><a href="#A-State-Machine-in-MyHDL" data-toc-modified-id="A-State-Machine-in-MyHDL-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>A State Machine in MyHDL</a></span></li><li><span><a href="#A-Counter-in-Amaranth" data-toc-modified-id="A-Counter-in-Amaranth-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>A Counter in Amaranth</a></span></li></ul></li><li><span><a href="#Displaying-Waveforms" data-toc-modified-id="Displaying-Waveforms-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Displaying Waveforms</a></span><ul class="toc-item"><li><span><a href="#Selecting-Display-Type" data-toc-modified-id="Selecting-Display-Type-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Selecting Display Type</a></span></li><li><span><a href="#Selecting-Waveforms-to-Display" data-toc-modified-id="Selecting-Waveforms-to-Display-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Selecting Waveforms to Display</a></span></li><li><span><a href="#Spacing-the-Waveforms" data-toc-modified-id="Spacing-the-Waveforms-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Spacing the Waveforms</a></span></li><li><span><a href="#Specifying-a-Time-Window" data-toc-modified-id="Specifying-a-Time-Window-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Specifying a Time Window</a></span></li><li><span><a href="#Showing-Grid-and-Cycle-Times" data-toc-modified-id="Showing-Grid-and-Cycle-Times-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Showing Grid and Cycle Times</a></span></li><li><span><a href="#Adding-Titles-and-Captions" data-toc-modified-id="Adding-Titles-and-Captions-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Adding Titles and Captions</a></span></li><li><span><a href="#Setting-the-Display-Size" data-toc-modified-id="Setting-the-Display-Size-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Setting the Display Size</a></span></li><li><span><a href="#Formatting-Waveform-Traces" data-toc-modified-id="Formatting-Waveform-Traces-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Formatting Waveform Traces</a></span></li><li><span><a href="#Setting-Default-Formatting" data-toc-modified-id="Setting-Default-Formatting-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Setting Default Formatting</a></span></li><li><span><a href="#Accessing-the-WaveJSON-Data" data-toc-modified-id="Accessing-the-WaveJSON-Data-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Accessing the WaveJSON Data</a></span></li><li><span><a href="#Skinning-It" data-toc-modified-id="Skinning-It-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Skinning It</a></span></li></ul></li><li><span><a href="#Displaying-Tables" data-toc-modified-id="Displaying-Tables-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Displaying Tables</a></span><ul class="toc-item"><li><span><a href="#HTML-Tables" data-toc-modified-id="HTML-Tables-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>HTML Tables</a></span></li><li><span><a href="#Text-Tables" data-toc-modified-id="Text-Tables-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Text Tables</a></span></li><li><span><a href="#Pandas-DataFrames" data-toc-modified-id="Pandas-DataFrames-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Pandas DataFrames</a></span></li></ul></li><li><span><a href="#Triggers" data-toc-modified-id="Triggers-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Triggers</a></span></li><li><span><a href="#Miscellaneous" data-toc-modified-id="Miscellaneous-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Miscellaneous</a></span><ul class="toc-item"><li><span><a href="#Convenience-Functions" data-toc-modified-id="Convenience-Functions-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Convenience Functions</a></span></li><li><span><a href="#Interactive-Waveform-Display" data-toc-modified-id="Interactive-Waveform-Display-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Interactive Waveform Display</a></span></li><li><span><a href="#Saving-Waveforms-to-a-File" data-toc-modified-id="Saving-Waveforms-to-a-File-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Saving Waveforms to a File</a></span></li><li><span><a href="#Using-myhdlpeek-in-a-Python-Script" data-toc-modified-id="Using-myhdlpeek-in-a-Python-Script-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Using myhdlpeek in a Python Script</a></span></li><li><span><a href="#Drawing-Waveforms-XKCD-Style" data-toc-modified-id="Drawing-Waveforms-XKCD-Style-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Drawing Waveforms XKCD-Style</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction
#
# New tools have appeared in the past few years to make design and documentation of digital systems
# easier than ever:
#
# * Python-based [hardware description languages](https://www.wikiwand.com/en/Hardware_description_language) like [MyHDL](myhdl.org) and [Amaranth](https://amaranth-lang.org/docs/amaranth/latest/) that can both synthesize and simulate a digital system.
# * [Jupyter notebooks](https://jupyter.org/) that combine explanatory text and executable code into a single, interactive document.
#
# But one thing that's missing is an easy way to show the results of digital system simulations inside a notebook. That's where `myhdlpeek` comes in.
#
# `myhdlpeek` lets you monitor signals in a MyHDL or Amaranth digital system simulation
# and display them as waveforms or as tables in a Jupyter notebook.
#
# `myhdlpeek` implements a `Peeker` object that monitors a signal and records
# the time and value when it changes.
# Just add multiple Peekers where you want to monitor something (even at sub-levels
# of a hierarchical design) and then view the collected data as waveforms or in a table
# with a single command.
# You can also select which signals are shown, set the beginning and
# ending times of the display, find portions of the waveforms where user-specified triggers occur,
# and much more.

# %% [markdown]
# # Installation
#
# Installing `myhdlpeek` is easy:
#
# ```bash
# $ pip install myhdlpeek
# ```
#
# ## Installing myhdl and Amaranth
#
# ###  myhdl
#
# Use the following generic pip command to install `myhdlpeek`:
#
# ``` bash
# $ pip install myhdl
# ```
#
# ###  Amaranth
# As stated in the [Amaranth documentation](https://amaranth-lang.org/docs/amaranth/latest/install.html), you can install the latest release of `Amaranth` using  the following generic pip command:
#
# ``` bash
# $ pip install --upgrade amaranth[builtin-yosys]
# ```

# %% [markdown]
# # Simple Multiplexer Example
#
# This example shows how to use the `myhdlpeek` module to monitor the inputs and output of a simple, two-input multiplexer.

# %% [markdown]
# ## MyHDL Version

# %%
from myhdl import *                 # Import the MyHDL module.
from myhdlpeek.myhdl import Peeker  # Import the MyHDL version of the myhdlpeeker module.


# Define the multiplexer module.
def mux(z, a, b, sel):
    """A simple multiplexer."""

    @always_comb
    def mux_logic():
        if sel == 1:
            z.next = a  # Signal a sent to mux output when sel is high.
        else:
            z.next = b  # Signal b sent to mux output when sel is low.
           
    return mux_logic

# Create some signals to attach to the multiplexer.
a, b, z = [Signal(0) for _ in range(3)]  # Integer signals for the inputs & output.
sel = Signal(bool(0))                    # Binary signal for the selector.

# Create some Peekers to monitor the multiplexer I/Os.
Peeker(a, 'a')         # Add a Peeker to the a input.
Peeker(b, 'b')         # Add a Peeker to the b input.
Peeker(z, 'z')         # Add a peeker to the z output.
Peeker(sel, 'select')  # Add a Peeker to the select input. The Peeker label doesn't have to match the signal name.

# Instantiate the multiplexer.
mux_1 = mux(z, a, b, sel)

# Create a test process to apply random patterns to the multiplexer.
from random import randrange
def test():
    '''Simple testbed generator that applies random inputs to the multiplexer.'''
    for _ in range(8):
        a.next, b.next, sel.next = randrange(8), randrange(8), randrange(2)
        yield delay(1)

# Create a simulator for the multiplexer, test process and the peekers.
sim = Simulation(mux_1, test(), *Peeker.instances())

# Run the simulation.
sim.run()

# Display the signal values as a table.
Peeker.to_html_table()

# Display the complete waveforms captured by all the Peekers.
Peeker.show_waveforms()

# Clear the Peekers for the next simulation.
Peeker.clear()
# Out:
# <class 'myhdl.StopSimulation'>: No more events
# <table>
# <thead>
# <tr><th style="text-align: right;">  Time</th><th style="text-align: right;">  a</th><th style="text-align: right;">  b</th><th style="text-align: right;">  select</th><th style="text-align: right;">  z</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">  7</td><td style="text-align: right;">  2</td><td style="text-align: right;">   False</td><td style="text-align: right;">  2</td></tr>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">  1</td><td style="text-align: right;">  6</td><td style="text-align: right;">   False</td><td style="text-align: right;">  6</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">  4</td><td style="text-align: right;">  4</td><td style="text-align: right;">   False</td><td style="text-align: right;">  4</td></tr>
# ...

# %% [markdown]
# ### MyHDL Version of a MUX using `enums`

# %%
from myhdl import *
from myhdlpeek import Peeker  # Import the myhdlpeeker module.

def mux(z, a, b, sel):
    """A simple multiplexer."""

    @always_comb
    def mux_logic():
        if sel == 1:
            z.next = a  # Signal a sent to mux output when sel is high.
        else:
            z.next = b  # Signal b sent to mux output when sel is low.
           
    return mux_logic

# Create some signals to attach to the multiplexer.
states = enum('zero', 'one', 'two', 'three', )
a, b, z = [Signal(states.zero) for _ in range(3)]  # Enum signals for the inputs & output.
sel = Signal(bool(0))                    # Binary signal for the selector.

# Create some Peekers to monitor the multiplexer I/Os.
Peeker.clear()         # Clear any existing Peekers. (Start with a clean slate.)
Peeker(a, 'a')         # Add a Peeker to the a input.
Peeker(b, 'b')         # Add a Peeker to the b input.
Peeker(z, 'z')         # Add a peeker to the z output.
Peeker(sel, 'select')  # Add a Peeker to the select input. The Peeker label doesn't have to match the signal name.

# Instantiate mux.
mux_1 = mux(z, a, b, sel)

# Create a simple testbed to apply random patterns to the multiplexer.
from random import choice, randrange
def test():
    '''Simple testbed generator that applies random inputs to the multiplexer.'''
    choices = [states.__dict__[k] for k in states._names]
    print("t  z a b sel")
    for _ in range(8):
        a.next, b.next, sel.next = choice(choices), choice(choices), randrange(0,2)
        yield delay(1)
        print("%d  %s %s %s %s" % (now(), z, a, b, sel))

# Simulate the multiplexer, testbed and the peekers.
sim = Simulation(mux_1, test(), *Peeker.instances()).run()

# Display table of signal values.
Peeker.to_html_table()

# Display the complete waveforms captured by all the Peekers. 
Peeker.show_waveforms()
# Out:
# t  z a b sel
# 1  three one three False
# 2  two two three 1
# 3  two three two 0
# 4  three three one 1
# 5  two zero two 0
# 6  three zero three 0
# 7  three three two 1
# 8  two zero two 0
# <class 'myhdl.StopSimulation'>: No more events
# <table>
# <thead>
# <tr><th style="text-align: right;">  Time</th><th>a    </th><th>b    </th><th style="text-align: right;">  select</th><th>z    </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td>one  </td><td>three</td><td style="text-align: right;">   False</td><td>three</td></tr>
# <tr><td style="text-align: right;">     1</td><td>two  </td><td>three</td><td style="text-align: right;">       1</td><td>two  </td></tr>
# <tr><td style="text-align: right;">     2</td><td>three</td><td>two  </td><td style="text-align: right;">       0</td><td>two  </td></tr>
# <tr><td style="text-align: right;">     3</td><td>three</td><td>one  </td><td style="text-align: right;">       1</td><td>three</td></tr>
# ...

# %% [markdown]
# ## Amaranth Version

# %%
from amaranth import *                 # Import the Amaranth module.
from amaranth.sim import *             # Import the Amaranth simulator.
from myhdlpeek.amaranth import Peeker  # Import the Amaranth version of the myhdlpeeker module.

# Define the multiplexer module.
class Multiplexer(Elaboratable):
    def __init__(self, width):
        self.a   = Signal(width)
        self.b   = Signal(width)
        self.sel = Signal(1)
        self.z   = Signal(width)
 
    def elaborate(self, platform):
        m = Module()
        m.d.comb += self.z.eq(Mux(self.sel, self.a, self.b))
        return m

# Instantiate the multiplexer with a data width of three bits.
mux = Multiplexer(width=3)

# Create some Peekers to monitor the multiplexer I/Os.
Peeker(mux.a, 'a')         # Add a Peeker to the a input.
Peeker(mux.b, 'b')         # Add a Peeker to the b input.
Peeker(mux.z, 'z')         # Add a peeker to the z output.
Peeker(mux.sel, 'select')  # Add a Peeker to the select input. The Peeker label doesn't have to match the signal name.

# Create a simulator object for the multiplexer.
sim = Simulator(mux)

# Create a test process to apply random patterns to the multiplexer.
def test_proc():
    from random import randint
    while True:
        yield mux.a.eq(randint(0,7))
        yield mux.b.eq(randint(0,7))
        yield mux.sel.eq(randint(0,1))
        yield Delay(0.1)  # Amaranth allows floats for delays.

# Add the test process to the simulator.
sim.add_process(test_proc)

# Assign the simulator object to the Peekers. Run the Peekers as if
# they were VCD writers since this is strictly a combinatorial design.
Peeker.assign_simulator(sim, use_vcd_writer=True)

# Run the simulation for eight cycles.
sim.run_until(1)

# Display the signal values as a table.
Peeker.to_html_table()

# Display the complete waveforms captured by all the Peekers.
Peeker.show_waveforms()

# Clear the Peekers for the next simulation.
Peeker.clear()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">        Time</th><th style="text-align: right;">  a</th><th style="text-align: right;">  b</th><th style="text-align: right;">  select</th><th style="text-align: right;">  z</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">           0</td><td style="text-align: right;">  4</td><td style="text-align: right;">  3</td><td style="text-align: right;">       0</td><td style="text-align: right;">  3</td></tr>
# <tr><td style="text-align: right;">100000000000</td><td style="text-align: right;">  2</td><td style="text-align: right;">  6</td><td style="text-align: right;">       0</td><td style="text-align: right;">  6</td></tr>
# <tr><td style="text-align: right;">200000000000</td><td style="text-align: right;">  1</td><td style="text-align: right;">  1</td><td style="text-align: right;">       1</td><td style="text-align: right;">  1</td></tr>
# ...

# %% [markdown]
# # Hierarchical Examples
#
# Peekers can also be used to monitor signals within sub-levels of a hierarchical design.
# Indices will be added to the signal names to distinguish them from one another.

# %% [markdown]
# ## An Adder in MyHDL

# %%
from myhdl import *
from myhdlpeek.myhdl import Peeker

def adder_bit(a, b, c_in, sum_, c_out):
    '''Single bit adder.'''
    @always_comb
    def adder_logic():
        sum_.next = a ^ b ^ c_in
        c_out.next = (a & b) | (a & c_in) | (b & c_in)
    
    # Add some peekers to monitor the inputs and outputs.
    # These will get replicated for each adder bit.
    Peeker(a, 'a')
    Peeker(b, 'b')
    Peeker(c_in, 'c_in')
    Peeker(sum_, 'sum')
    Peeker(c_out, 'c_out')
    
    return adder_logic

def adder(a, b, sum_):
    '''Connect single-bit adders to create a complete adder.'''
    c = [Signal(bool(0)) for _ in range(len(a)+1)] # Carry signals between stages.
    s = [Signal(bool(0)) for _ in range(len(a))]   # Sum bit for each stage.
    stages = []  # Storage for adder bit instances.
    
    # Create the adder bits and connect them together.
    for i in range(len(a)):
        stages.append( adder_bit(a=a(i), b=b(i), sum_=s[i], c_in=c[i], c_out=c[i+1]) )
    
    # Concatenate the sum bits and send them out on the sum_ output.
    @always_comb
    def make_sum():
        sum_.next = ConcatSignal(*reversed(s))
    
    return instances()  # Return all the adder stage instances.

# Create signals for interfacing to the adder.
a, b, sum_ = [Signal(intbv(0,0,8)) for _ in range(3)]

# Instantiate the adder.
add_1 = adder(a=a, b=b, sum_=sum_)

# Create some more peekers to monitor the top-level buses.
Peeker(a, 'a_bus')
Peeker(b, 'b_bus')
Peeker(sum_, 'sum_bus')

# Create a test process that applies random inputs to the adder.
from random import randrange
def adder_test(num_steps):
    for _ in range(num_steps):
        a.next, b.next = randrange(0, a.max), randrange(0, a.max)
        yield delay(1)

# Simulate the adder, test process and peekers.
Simulation(add_1, adder_test(20), *Peeker.instances()).run()

# Show all the signals in the hierarchical design.
Peeker.show_waveforms()

Peeker.clear()
# Out:
# <class 'myhdl.StopSimulation'>: No more events

# %% [markdown]
# ## An ALU in Amaranth

# %%
from amaranth import *
from amaranth.sim import *
from myhdlpeek.amaranth import Peeker

class Adder(Elaboratable):
    '''Adder module.'''
    def __init__(self, width):
        self.a   = Signal(width)
        self.b   = Signal(width)
        self.o   = Signal(width)
        
        # Peekers for adder I/O.
        Peeker(self.a, "ADDER_A")
        Peeker(self.b, "ADDER_B")
        Peeker(self.o, "SUM")
 
    def elaborate(self, platform):
        m = Module()
        m.d.comb += self.o.eq(self.a + self.b)
        return m

class Subtractor(Elaboratable):
    '''Subtractor module.'''
    def __init__(self, width):
        self.a   = Signal(width)
        self.b   = Signal(width)
        self.o   = Signal(width)

        # Peekers for subtractor I/O.
        Peeker(self.a, "SUB_A")
        Peeker(self.b, "SUB_B")
        Peeker(self.o, "DIFF")
 
    def elaborate(self, platform):
        m = Module()
        m.d.comb += self.o.eq(self.a - self.b)
        return m

class ALU(Elaboratable):
    '''ALU made up of an adder and a subtractor.'''
    def __init__(self, width):
        self.op  = Signal()
        self.a   = Signal(width)
        self.b   = Signal(width)
        self.o   = Signal(width)
        
        # Peekers for ALU I/O.
        Peeker(self.a, "A")
        Peeker(self.b, "B")
        Peeker(self.op, "ADD/SUB")
        Peeker(self.o, "OUTPUT")
 
        self.add = Adder(width)
        self.sub = Subtractor(width)
 
    def elaborate(self, platform):
        m = Module()
        m.submodules.add = self.add
        m.submodules.sub = self.sub
        m.d.comb += [
            self.add.a.eq(self.a),
            self.sub.a.eq(self.a),
            self.add.b.eq(self.b),
            self.sub.b.eq(self.b),
        ]
        with m.If(self.op):
            # Subtract a-b when op==1.
            m.d.comb += self.o.eq(self.sub.o)
        with m.Else():
            # Add a+b when op==0.
            m.d.comb += self.o.eq(self.add.o)
        return m

alu = ALU(width=4)  # Instantiate a four-bit ALU.

sim = Simulator(alu)

# Create test process fo applying random inputs and add/sub operations.
def test_proc():
    from random import randint
    while True:
        yield alu.a.eq(randint(0,15))
        yield alu.b.eq(randint(0,15))
        yield alu.op.eq(randint(0,1))
        yield Delay(1)

# Add the test process to the simulator.
sim.add_process(test_proc)

# Assign the simulator object to the Peekers. Run the Peekers as if
# they were VCD writers since this is strictly a combinatorial design.
Peeker.assign_simulator(sim, use_vcd_writer=True)

# Run the simulation for twenty cycles.
sim.run_until(20)

# Display the complete waveforms captured by all the Peekers.
# An explicit ordering of the Peekers is given in this case.
Peeker.show_waveforms("ADDER_A ADDER_B SUM SUB_A SUB_B DIFF A B ADD/SUB OUTPUT")

Peeker.clear()

# %% [markdown]
# # Sequential Examples

# %% [markdown]
# ## A State Machine in MyHDL

# %%
from myhdl import *
from myhdlpeek.myhdl import Peeker

states = enum('S0', 'S1', 'S2', 'S3')

def fsm(clk, sel, out):
    """A simple finite state machine."""
    
    s = Signal(states.S0)

    @always_seq(clk.posedge, reset=None)
    def next_state():
        if sel:
            # S0 -> S1 -> S2 -> S3 -> S0 -> ...
            if s == states.S0:
                s.next = states.S1
            elif s == states.S1:
                s.next = states.S2
            elif s == states.S2:
                s.next = states.S3
            else:
                s.next = states.S0
        else:
            # S0 -> S3 -> S2 -> S1 -> S0 -> ...
            if s == states.S0:
                s.next = states.S3
            elif s == states.S1:
                s.next = states.S0
            elif s == states.S2:
                s.next = states.S1
            else:
                s.next = states.S2
                
    @always_comb
    def output():
        out.next = s
           
    return next_state, output

# Create some signals to attach to the FSM.
clk, sel, out = Signal(bool(0)), Signal(bool(0)), Signal(states.S0)

# Create some Peekers to monitor the FSM I/Os.
Peeker(clk, 'clk')         # Add a Peeker to the a input.
Peeker(sel, 'sel')         # Add a Peeker to the b input.
Peeker(out, 'out')         # Add a peeker to the z output.

# Instantiate the FSM.
fsm_1 = fsm(clk, sel, out)

# Create a test process to cause random state changes.
def test():
    from random import randint
    choices = [states.__dict__[k] for k in states._names]
    for _ in range(10):
        sel.next = randint(0,1)
        clk.next = 0
        yield delay(1)
        clk.next = 1
        yield delay(1)

# Simulate the FSM, test process and the peekers.
sim = Simulation(fsm_1, test(), *Peeker.instances()).run()

# Display the complete waveforms captured by all the Peekers. 
Peeker.show_waveforms()

Peeker.clear()
# Out:
# <class 'myhdl.StopSimulation'>: No more events

# %% [markdown]
# ## A Counter in Amaranth

# %%
from amaranth import *
from amaranth.sim import *
from myhdlpeek.amaranth import Peeker
  
class Counter(Elaboratable):
    '''A simple counter that increments at every clock cycle.'''
    def __init__(self, width):
        self.v = Signal(width)
        
        # Create monitors for the counter value and individual bits.
        Peeker(self.v, 'count')
        for bit in self.v:
            Peeker(bit, self.v.name + '_bit')
 
    def elaborate(self, platform):
        m = Module()
        m.d.sync += self.v.eq(self.v + 1)
        return m
 
counter = Counter(width=4)

sim = Simulator(counter)

# Add a 1 MHz clock to the simulator.
sim.add_clock(1e-6)

# Assign the simulator object to the Peekers. Since this is a sequential
# design driven by a clock, the Peekers can execute as processes instead
# of as VCD writers.
Peeker.assign_simulator(sim)

# Simulate for 20 microseconds.
sim.run_until(20e-6)

Peeker.show_waveforms()

Peeker.clear()

# %% [markdown]
# # Displaying Waveforms
#
# Once the simulation has run and all the Peekers have gathered their signal traces, you can show the collected data in various ways.
# The options that affect the waveform display will be illustrated using the waveforms generated by re-running the [hierarchical adder example](#An-Adder-in-MyHDL).

# %%
from myhdl import *
from myhdlpeek.myhdl import Peeker

# Create signals for interfacing to the adder.
a, b, sum_ = [Signal(intbv(0,0,8)) for _ in range(3)]

# Instantiate the adder.
add_1 = adder(a=a, b=b, sum_=sum_)

# Create some more peekers to monitor the top-level buses.
Peeker(a, 'a_bus')
Peeker(b, 'b_bus')
Peeker(sum_, 'sum_bus')

# Simulate the adder, test process and peekers.
Simulation(add_1, adder_test(8), *Peeker.instances()).run()
# Out:
# <class 'myhdl.StopSimulation'>: No more events
# 0

# %% [markdown]
# ## Selecting Display Type
#
# You can display waveforms using either the [`matplotlib`](https://matplotlib.org/) or
# [`wavedrom`](https://wavedrom.com/) libraries.
# The `Peeker.show_waveforms(...)` function will use whichever library is active.
# `matplotlib` is the default, but that can be changed like so:
#
# ```py
# Peeker.config_defaults(use_wavedrom=True)
# ```
#
# To change back to `matplotlib`, use:
#
# ```py
# Peeker.config_defaults(use_wavedrom=False)
# ```
#
# If you want to explicitly use `matplotlib` or `wavedrom` for displaying waveforms, that can be done by replacing `Peeker.show_waveforms(...)` with `Peeker.to_matplotlib(...)` or `Peeker.to_wavedrom(...)`, respectively.
#
# If you choose to use `wavedrom`, you also need to set a flag depending upon whether you are using Jupyter or JupyterLab for your notebook:
#
# ```py
# Peeker.config_defaults(use_wavedrom=True, use_jupyter=True)   # If using Jupyter.
#
# Peeker.config_defaults(use_wavedrom=True, use_jupyter=False)  # If using JupyterLab.
# ```

# %% [markdown]
# ## Selecting Waveforms to Display
#
# By default, `show_waveforms()` displays all the captured waveforms. But you can also specify a subset of the waveforms for display:

# %%
Peeker.show_waveforms('a_bus', 'b_bus', 'sum_bus', 'sum[2]', 'sum[1]', 'sum[0]');

# %% [markdown]
# If you don't like typing all those quotation marks, you can place multiple, space-separated Peeker names inside a string:

# %%
Peeker.show_waveforms('a_bus b_bus sum_bus sum[2] sum[1] sum[0]');

# %% [markdown]
# ## Spacing the Waveforms
#
# If you want to place some space between the waveforms, just insert a string that doesn't match any peeker's name (I like to use a `|` character for that):

# %%
Peeker.show_waveforms('a_bus b_bus | sum_bus sum[2] sum[1] sum[0]');

# %% [markdown]
# ## Specifying a Time Window
#
# To show only a segment of the waveforms, use the `start_time` and `stop_time` options:

# %%
signals = 'a_bus b_bus | sum_bus sum[0]'
Peeker.show_waveforms(signals, start_time=5, stop_time=15);

# %% [markdown]
# ## Showing Grid and Cycle Times
#
# If it's hard to tell the interval covered by the waveforms, you can turn on the display of cycle times using the `tick` or `tock` options:

# %%
Peeker.show_waveforms(signals, start_time=5, stop_time=15, tick=True);

# %%
Peeker.show_waveforms(signals, start_time=5, stop_time=15, tock=True);

# %% [markdown]
# You can set the format for the `tick`/`tock` labels using the optional `time_fmt` argument ([here](https://matplotlib.org/3.2.1/api/text_api.html#matplotlib.text.Text) is a list of all the formatting options):

# %%
Peeker.show_waveforms(signals, stop_time=15, tock=True,
                      time_fmt={'color':'#080', 'fontweight':'heavy', 'fontstyle':'oblique'});

# %% [markdown]
# When using the `matplotlib` display, you can also format the grid lines with the optional `grid_fmt` argument ([here](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) is a list of all the formatting options):

# %%
Peeker.show_waveforms(signals, stop_time=15, grid_fmt={'color':'#888', 'dashes':(10,4)});

# %% [markdown]
# And if you don't want any grid at all, then make it transparent by setting it's `alpha` to zero:

# %%
Peeker.show_waveforms(signals, stop_time=15, grid_fmt={'alpha':0});

# %% [markdown]
# ## Adding Titles and Captions
#
# You can also add a title and caption to your work:

# %%
Peeker.show_waveforms(signals, start_time=5, stop_time=15, tock=True,
                   title='Multi-Bit, Hierarchical Adder', caption='It really works!');

# %% [markdown]
# If you're displaying waveforms with `matplotlib`, the title and caption can be formatted using the optional `title_fmt` and `caption_fmt` arguments ([here](https://matplotlib.org/3.2.1/api/text_api.html#matplotlib.text.Text) is a list of all the formatting options):

# %%
Peeker.show_waveforms(signals, title='Hierarchical Adder', title_fmt={'fontweight': 'bold'},
                     caption='It really works!', caption_fmt={'color':'#f0f', 'fontsize':13});

# %% [markdown]
# ## Setting the Display Size
#
# The `width` and `height` options let you expand or reduce the entire waveform display:

# %%
Peeker.show_waveforms(signals, width=8, height=4);  # In matplotlib, width/height is in inches.

# %% [markdown]
# Sometimes you'll have a long simulation that creates an unreadable display because it's squeezed
# into the width of the page. You can restore legibility by setting `width` *wider* than the page
# and then using the scroll bars to view the waveforms (this only works when using `wavedrom`):

# %%
Simulation(add_1, adder_test(100), *Peeker.instances()).run()  # Create a longer trace.
Peeker.config_defaults(use_jupyter=True)
Peeker.to_wavedrom(signals, stop_time=100, width=4000)  # In wavedrom, width is in pixels.
Peeker.clear_traces()
Simulation(add_1, adder_test(8), *Peeker.instances()).run()  # Restore the shorter trace.
# Out:
# <class 'myhdl.StopSimulation'>: No more events
# ...

# %% [markdown]
# ## Formatting Waveform Traces

# %% [markdown]
# You can alter the appearance of the waveform traces using the `line_fmt`, `name_fmt`, `data_fmt`, and `slope` arguments.

# %% [markdown]
# The `line_fmt` argument controls the way the trace line is drawn.
# One way to set this option is as a `matplotlib` [format string](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html):

# %%
Peeker.show_waveforms(signals, stop_time=15, line_fmt='--g');  # Dashed green line for traces.

# %% [markdown]
# Alternatively, you can use a `dict` of
# [these options](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D):

# %%
Peeker.show_waveforms(signals, stop_time=15, line_fmt={'color':'#800', 'linewidth':2.5});

# %% [markdown]
# The `name_fmt` and `data_fmt` arguments control the [text formatting](https://matplotlib.org/3.2.1/api/text_api.html#matplotlib.text.Text) of the trace names and the data values:

# %%
Peeker.show_waveforms(signals, stop_time=15,
                      name_fmt={'color':'#800', 'fontweight':'bold'},
                      data_fmt={'color':'#080', 'fontstyle':'oblique', 'fontsize':14});

# %% [markdown]
# Also, the `data_fmt` argument can contain a `repr` item that provides a function for representing the data value:

# %%
Peeker.show_waveforms(signals, stop_time=15, data_fmt={'repr': hex, 'fontstyle': 'oblique'});

# %% [markdown]
# The transition interval of the traces is controlled by the `slope` argument which is 0.2 by default.
# Set it to zero if you want box-like bus packets:

# %%
Peeker.show_waveforms(signals, stop_time=15, slope=0);

# %% [markdown]
# You can change the formatting for a specific trace as follows:

# %%
sum_pkr = Peeker.get('sum_bus')
sum_pkr.config(line_fmt=':r', slope=0, name_fmt={'fontweight':'bold'})
Peeker.show_waveforms(signals, stop_time=15);

# %% [markdown]
# ## Setting Default Formatting
#
# You can specify a global formatting that applies to all displays of waveform traces in a notebook:

# %%
Peeker.config_defaults(data_fmt={'color':'blue', 'fontsize':14, 'fontweight':'heavy'})
Peeker.show_waveforms(signals, stop_time=15)  # Has large, bold, blue data values.
Peeker.show_waveforms(signals, stop_time=10)  # Also has large, bold, blue data values.
Peeker.config_defaults(data_fmt={})

# %% [markdown]
# With regards to precedence, the formatting options are applied in this order:
#
# 1. Options specified with `Peeker.config_defaults()`.
# 2. Options specified for a specific Peeker using the `config()` method.
# 3. Options specified as arguments to the `show_waveforms()` function.

# %% [markdown]
# ## Accessing the WaveJSON Data
#
# When using `wavedrom`, you might want to access the WaveJSON data directly to exert more control over the waveform display. This is done with the `to_wavejson()` method:

# %%
wavejson = Peeker.to_wavejson(signals)
wavejson
# Out:
# {'signal': [{'name': 'a_bus',
#    'wave': '====.===',
#    'data': ['5', '7', '4', '3', '4', '6', '3']},
#   {'name': 'b_bus',
#    'wave': '========',
#    'data': ['4', '2', '5', '7', '6', '0', '5', '6']},
#   {},
#   {'name': 'sum_bus',
#    'wave': '=..=====',
#    'data': ['1', '2', '1', '4', '3', '1']},
#   {'name': 'sum[0]', 'wave': '1..0101.'}]}

# %% [markdown]
# After you manipulate the WaveJSON data, you can display it using the `wavejson_to_wavedrom()` function:

# %%
from myhdlpeek import wavejson_to_wavedrom
wavejson_to_wavedrom(wavejson)
# Out:
# <div><script type="WaveDrom">{"signal": [{"name": "a_bus", "wave": "====.===", "data": ["5", "7", "4", "3", "4", "6", "3"]}, {"name": "b_bus", "wave": "========", "data": ["4", "2", "5", "7", "6", "0", "5", "6"]}, {}, {"name": "sum_bus", "wave": "=..=====", "data": ["1", "2", "1", "4", "3", "1"]}, {"name": "sum[0]", "wave": "1..0101."}]}</script></div>

# %% [markdown]
# ## Skinning It

# %% [markdown]
# The `skin` option lets you choose the set of graphic elements that are used to draw the `wavedrom` waveforms.
# Currently, the only allowed values are `default` and `narrow`.

# %%
Peeker.to_wavedrom(signals, skin='narrow')
Peeker.to_wavedrom(signals)
# Out:
# <div><script type="WaveDrom">{"signal": [{"name": "a_bus", "wave": "====.===", "data": ["5", "7", "4", "3", "4", "6", "3"]}, {"name": "b_bus", "wave": "========", "data": ["4", "2", "5", "7", "6", "0", "5", "6"]}, {}, {"name": "sum_bus", "wave": "=..=====", "data": ["1", "2", "1", "4", "3", "1"]}, {"name": "sum[0]", "wave": "1..0101."}]}</script></div>
# <div><script type="WaveDrom">{"signal": [{"name": "a_bus", "wave": "====.===", "data": ["5", "7", "4", "3", "4", "6", "3"]}, {"name": "b_bus", "wave": "========", "data": ["4", "2", "5", "7", "6", "0", "5", "6"]}, {}, {"name": "sum_bus", "wave": "=..=====", "data": ["1", "2", "1", "4", "3", "1"]}, {"name": "sum[0]", "wave": "1..0101."}]}</script></div>

# %% [markdown]
# # Displaying Tables
#
# In addition to waveforms, `myhdlpeek` also lets you display the captured traces as tables.
# To demonstrate, I'll use our old friend the multiplexer:

# %% [markdown]
# ## HTML Tables
#
# Once a simulation has run, you can display the results using a table instead of waveforms:

# %%
Peeker.to_html_table()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Time</th><th style="text-align: right;">  a_bus</th><th style="text-align: right;">  b_bus</th><th style="text-align: right;">  sum_bus</th><th>a[0]  </th><th>b[0]  </th><th>c_in[0]  </th><th>c_out[0]  </th><th>sum[0]  </th><th>a[1]  </th><th>b[1]  </th><th>c_in[1]  </th><th>c_out[1]  </th><th>sum[1]  </th><th>a[2]  </th><th>b[2]  </th><th>c_in[2]  </th><th>c_out[2]  </th><th>sum[2]  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     0</td><td style="text-align: right;">      5</td><td style="text-align: right;">      4</td><td style="text-align: right;">        1</td><td>True  </td><td>False </td><td>False    </td><td>False     </td><td>True    </td><td>False </td><td>False </td><td>False    </td><td>False     </td><td>False   </td><td>True  </td><td>True  </td><td>False    </td><td>True      </td><td>False   </td></tr>
# ...

# %% [markdown]
# You can use all the same options for showing waveforms with tabular output:

# %%
Peeker.to_html_table('a_bus b_bus sum_bus', start_time=3) # Select and change order of signals, and set start time.
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Time</th><th style="text-align: right;">  a_bus</th><th style="text-align: right;">  b_bus</th><th style="text-align: right;">  sum_bus</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">      3</td><td style="text-align: right;">      7</td><td style="text-align: right;">        2</td></tr>
# <tr><td style="text-align: right;">     4</td><td style="text-align: right;">      3</td><td style="text-align: right;">      6</td><td style="text-align: right;">        1</td></tr>
# <tr><td style="text-align: right;">     5</td><td style="text-align: right;">      4</td><td style="text-align: right;">      0</td><td style="text-align: right;">        4</td></tr>
# <tr><td style="text-align: right;">     6</td><td style="text-align: right;">      6</td><td style="text-align: right;">      5</td><td style="text-align: right;">        3</td></tr>
# ...

# %% [markdown]
# ## Text Tables
#
# There's even a version for use in console mode (outside of the Jupyter environment):

# %%
Peeker.to_text_table('a_bus b_bus sum_bus')
# Out:
#   Time    a_bus    b_bus    sum_bus
# ------  -------  -------  ---------
#      0        5        4          1
#      1        7        2          1
#      2        4        5          1
#      3        3        7          2
#      4        3        6          1
#      5        4        0          4
#      6        6        5          3
#      7        3        6          1

# %% [markdown]
# ## Pandas DataFrames
#
# You can also export the traces captured with `myhdlpeek` as a Pandas Data Frame:

# %%
Peeker.to_dataframe()
# Out:
#   a_bus b_bus sum_bus   a[0]   b[0] c_in[0] c_out[0] sum[0]   a[1]   b[1]  \
# 0     5     4       1   True  False   False    False   True  False  False
# 1     7     2       1   True  False   False    False   True   True   True
# 2     4     5       1  False   True   False    False   True  False  False
# 3     3     7       2   True   True   False     True  False   True   True
# 4     3     6       1   True  False   False    False   True   True   True
# 5     4     0       4  False  False   False    False  False  False  False
# 6     6     5       3  False   True   False    False   True   True  False
# 7     3     6       1   True  False   False    False   True   True   True
#
#   c_in[1] c_out[1] sum[1]   a[2]   b[2] c_in[2] c_out[2] sum[2]
# 0   False    False  False   True   True   False     True  False
# 1   False     True  False   True  False    True     True  False
# 2   False    False  False   True   True   False     True  False
# ...

# %% [markdown]
# The same options that were used for tabular output are available for exporting the DataFrame:

# %%
Peeker.to_dataframe('a_bus b_bus sum_bus', start_time=3, stop_time=6) # Select the traces to export and set the start and stop times.
# Out:
#   a_bus b_bus sum_bus
# 3     3     7       2
# 4     3     6       1
# 5     4     0       4
# 6     6     5       3

# %% [markdown]
# # Triggers
#
# If you capture large signal traces, it's useful to be able to find portions where particular things happen.
# *Triggers* are used for this.
# These are analogous to the trigger function on logic analyzers and oscilloscopes.
#
# Triggers are created by performing operations on `Trace` objects.
# A `Trace` is just a list of values for a signal and the times at which they occurred.
# Every `Peeker` object contains a `Trace` to record the values observed by the `Peeker`.
#
# Arithmetic (`+, -, *, %, /, //, **, <<, >>, abs`), logical (`&, |, ^, ~`), and comparison (`==, !=, <, >, <=, >=`) operations
# can be performed on `Trace` and `Peeker` objects to create a new `Trace` as a result:
#
#     <Trace|Peeker> op <Trace|Peeker|integer|float> => Trace
#
# There is also a `delay()` method for creating a time-shifted version of a `Trace` (useful for
# detecting edges):
#
#     <Trace|Peeker>.delay(<integer>) => Trace
#
# The times at which the resulting trace is `True` (i.e., non-zero) can be extracted as a list:
#
#     <Trace|Peeker>.trig_times() => [t0, t1, ...]
#
# These time values can be used to set the `start_time` parameter when displaying waveforms or tables:
#
# ```py
# trigs = trc.trig_times()
# Peeker.show_waveforms(..., start_time=trigs[0])
# ```
#
# I'll demonstrate the creation of triggers using `Trace` objects containing random values.
# (These same operations can be performed on `Peeker` objects;
# it's just easier to create a `Trace`.)

# %%
from random import randrange
from myhdlpeek import Trace, Sample, show_traces

def create_random_trace(name, num_bits, num_samples):
    trace = Trace()
    trace.name = name
    trace.num_bits = num_bits
    for i in range(num_samples):
        trace.append(Sample(i, randrange(0,2**num_bits)))
    return trace

trc1 = create_random_trace('Trc1', 4, 100)
trc2 = create_random_trace('Trc2', 1, 100)

Peeker.show_traces(trc1, trc2, stop_time=20);

# %% [markdown]
# A common trigger is to look for a positive-going edge on a signal.
# This can be done by logically-ANDing the signal to a time-delayed and inverted version of itself:

# %%
posedge_trc = trc2 & ~trc2.delay(1)    # Create trigger trace that is 1 whenever trc2 has a rising edge.
posedge_trc.name = 'Positive Edge'
trigs = posedge_trc.trig_times()       # Get times at which the trigger trace is 1.
print('Trigger times:', trigs)
start_time = trigs[0]                  # Start waveform display at the first trigger.
stop_time = start_time+20              # Stop waveform display after 20 time units.
Peeker.show_traces(trc2, posedge_trc, start_time=start_time, stop_time=stop_time, tock=True);
# Out:
# Trigger times: [4, 8, 11, 14, 21, 25, 27, 32, 34, 40, 43, 46, 56, 58, 62, 68, 74, 76, 78, 84, 89, 93, 97, 99]

# %% [markdown]
# Naturally, there are convenience functions for these common cases: `posedge()`, `negedge()` and `anyedge()`:

# %%
posedge_trc = trc2.posedge(); posedge_trc.name = 'Positive Edge'
negedge_trc = trc2.negedge(); negedge_trc.name = 'Negative Edge'
anyedge_trc = trc2.anyedge(); anyedge_trc.name = 'Any Edge'
Peeker.show_traces(trc2, posedge_trc, negedge_trc, anyedge_trc, stop_time=20);

# %% [markdown]
# Another common trigger is to look for when a bus has a certain value:

# %%
val_trc = trc1 == 7  # Create a trigger trace that is 1 whenever trc1 has the value 7.
trigs = val_trc.trig_times()
Peeker.show_traces(trc1, val_trc, start_time=trigs[0]-5, stop_time=trigs[0]+15);

# %% [markdown]
# Or detect when a bus is between two values:

# %%
val_trc = (5 <= trc1) & (trc1 <= 8)  # Trigger when trace value is in range [5,8].
trigs = val_trc.trig_times()
Peeker.show_traces(trc1, val_trc, start_time=trigs[0], stop_time=trigs[0]+20);

# %% [markdown]
# Or trigger when several bits of a bus have a certain value:

# %%
bit_val_trc = ((trc1 & 0b0110)>>1) == 3 # Trigger when bits 1 and 2 are both on (trc1 is 6, 7, 14 or 15).
trig = bit_val_trc.trig_times()[0]
Peeker.show_traces(trc1, bit_val_trc, start_time=trig-5, stop_time=trig+15);

# %% [markdown]
# Complicated triggers are possible. Here's one that triggers when consecutive bus values differ by more than 10:

# %%
diff_trc = (abs(trc1 - trc1.delay(1))) > 10
trig = diff_trc.trig_times()[0]
Peeker.show_traces(trc1, diff_trc, start_time=trig-5, stop_time=trig+15);

# %% [markdown]
# Since the output of operations on `Trace`s is another `Trace`, it's possible to
# concatenate several operations to get a concise trigger expression:

# %%
trig = ((5 <= trc1) & (trc1 <= 8)).trig_times()[0]
Peeker.show_traces(trc1, val_trc, start_time=trig, stop_time=trig+20);

# %% [markdown]
# # Miscellaneous

# %% [markdown]
# ## Convenience Functions
#
# There are a few convenience functions for displaying trace waveforms and tables:
#
# * `clear_traces()` is equivalent to `Peeker.clear_traces()`
# * `show_traces(...)` is equivalent to `Peeker.show_traces(...)`
# * `show_waveforms(...)` is equivalent to `Peeker.show_waveforms(...)`.
# * `show_text_table(...)` is equivalent to `Peeker.to_text_table(...)`.
# * `show_html_table(...)` is equivalent to `Peeker.to_html_table(...)`.
# * `export_dataframe(...)` is equivalent to `Peeker.to_dataframe(...)`.

# %% [markdown]
# ## Interactive Waveform Display
#
# Up to now, all the waveform traces in this notebook have been rendered inline, but you can interact with the display using the `%matplotlib notebook` magic command:

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
Peeker.show_traces(trc1, val_trc, height=1, tock=True);
# Out:
# <div id='496848f2-a794-434c-a61d-eba7713b6057'></div>

# %% [markdown]
# (I'll return to inline image rendering for the remainder of this notebook.)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Saving Waveforms to a File
#
# Both `show_waveforms()` and `show_traces()` return a
# [Figure](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure)
# object and a list of
# [Axes](https://matplotlib.org/3.1.0/api/axes_api.html?highlight=axes#the-axes-class)
# objects for the waveforms.
# You can do a bunch of things to the `Figure` object, but the most obvious is to use the [`savefig()`](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure.savefig)
# method to store the traces in an image file:

# %%
fig, axes = Peeker.show_traces(trc1, val_trc)
fig.savefig('traces.svg')

# %% [markdown]
# ## Using myhdlpeek in a Python Script
#
# In addition to Jupyter notebooks, you can also use `myhdlpeek` in stand-alone Python scripts as shown below with the multiplexer example:
#
# ```py
# from myhdl import *
# from myhdlpeek.myhdl import Peeker
#
# # Define the multiplexer module.
# def mux(z, a, b, sel):
#
#     @always_comb
#     def mux_logic():
#         if sel == 1:
#             z.next = a
#         else:
#             z.next = b
#
#     return mux_logic
#
# # Create some signals to attach to the multiplexer.
# a, b, z = [Signal(0) for _ in range(3)]
# sel = Signal(bool(0))
#
# # Create some Peekers to monitor the multiplexer I/Os.
# Peeker(a, 'a')
# Peeker(b, 'b')
# Peeker(z, 'z')
# Peeker(sel, 'select')
#
# # Instantiate the multiplexer.
# mux_1 = mux(z, a, b, sel)
#
# # Create a test process to apply random patterns to the multiplexer.
# from random import randrange
# def test():
#     for _ in range(8):
#         a.next, b.next, sel.next = randrange(8), randrange(8), randrange(2)
#         yield delay(1)
#
# # Create & run a simulator for the multiplexer, test process and the peekers.
# Simulation(mux_1, test(), *Peeker.instances()).run()
#
# # Display the complete waveforms captured by all the Peekers.
# Peeker.show_waveforms()
#
# # Show the waveforms in a dialog window.
# import matplotlib.pyplot as plt
# plt.show()
#
# ```

# %% [markdown]
# ## Drawing Waveforms XKCD-Style
#
# No use of the `matplotlib` library is complete without a demonstration of XKCD styling:

# %%
import matplotlib.pyplot as plt
with plt.xkcd():
    Peeker.show_traces(trc1, val_trc, stop_time=20)
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# ...
